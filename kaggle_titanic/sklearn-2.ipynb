# %% [markdown]
# # Using the standard deviation and mean random number method to fill empty data
#
# Accuracies is much worse than dropna()

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


from sklearn.neural_network import MLPClassifier, MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import matplotlib
import random

# %%
train_url = 'train.csv'
gender_submission_url = 'gender_submission.csv'
test_url = 'test.csv'

# %%
df = pd.read_csv(train_url)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Let's look more closely at the data

# %%
print('There are',df['PassengerId'].count(),'pieces of passenger data (by PassengerId)')
print('-------')
print('There are',df[df["Pclass"]==1]['Pclass'].count(),'people in upper social class')
print('There are',df[df["Pclass"]==2]['Pclass'].count(),'people in middle social class')
print('There are',df[df["Pclass"]==3]['Pclass'].count(),'people in lower social class')
print('-------')
print('There are',df[df["SibSp"]==0]['SibSp'].count(),'people with no siblings or spouses aboard')
print('There are',df[df["SibSp"]>=1]['SibSp'].count(),'people with siblings or spouses aboard')
print('-------')
# Out:
# There are 891 pieces of passenger data (by PassengerId)
# -------
# There are 216 people in upper social class
# There are 184 people in middle social class
# There are 491 people in lower social class
# -------
# There are 608 people with no siblings or spouses aboard
# There are 283 people with siblings or spouses aboard
# -------

# %% [markdown]
# ## Now to clean the data

# %% [markdown]
# Change Gender male to 0, female to 1

# %%
df['Sex'].replace('male',0,inplace=True)
df['Sex'].replace('female',1,inplace=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %% [markdown]
# We will drop:
#
# Ticket, Name, PassengerId
#
# as they are probably not important in training the model

# %%
df = df.drop(["Ticket","Name","PassengerId"],axis=1)
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    0  22.0      1      0   7.2500   NaN        S
# 1         1       1    1  38.0      1      0  71.2833   C85        C
# 2         1       3    1  26.0      0      0   7.9250   NaN        S
# 3         1       1    1  35.0      1      0  53.1000  C123        S
# 4         0       3    0  35.0      0      0   8.0500   NaN        S

# %% [markdown]
# We will remove cabin here for now, because it needs further data manipulation because of their alphabets and  irregular data. We can choose to use Excel or other spreadsheets to view and clean data if we wish.
#
# Cabin is important to because it shows us their positions in the ship when Titanic went down at night

# %%
df = df.drop(["Cabin"],axis=1)
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    0  22.0      1      0   7.2500        S
# 1         1       1    1  38.0      1      0  71.2833        C
# 2         1       3    1  26.0      0      0   7.9250        S
# 3         1       1    1  35.0      1      0  53.1000        S
# 4         0       3    0  35.0      0      0   8.0500        S

# %% [markdown]
# Now the data looks almost clean and all in numerical 'weights'.
# We will change the emarked to numbers as well
#
# Southampton = S = 0,
# Cherbourg = C = 1,
# Queenstown = Q = 2

# %%
df['Embarked'].replace('S',0,inplace=True)
df['Embarked'].replace('C',1,inplace=True)
df['Embarked'].replace('Q',1,inplace=True)
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    0  22.0      1      0   7.2500       0.0
# 1         1       1    1  38.0      1      0  71.2833       1.0
# 2         1       3    1  26.0      0      0   7.9250       0.0
# 3         1       1    1  35.0      1      0  53.1000       0.0
# 4         0       3    0  35.0      0      0   8.0500       0.0

# %% [markdown]
# We will now correct all rows of data with EMPTY or NaN values
#
# Here instead of dropping all NaN values, we should fill
# the empty values with random numbers between standard deviation and mean
#
# use df['Age'].isnull().values.any() to check for empty values

# %%
## Here instead of dropping all NaN values, we should fill 
## the empty values with random numbers between standard deviation and mean
## use df['Age'].isnull().values.any() to check for empty values
## Age, Embarked has empty values
# are there any null values in df left?
df['Survived'].isnull().values.any()
# Out:
# False

# %%
std_age = df['Age'].std()
mean_age = df['Age'].std()
df['Age'].fillna(random.randint(int(std_age),int(mean_age)), inplace=True)

std_age = df['Embarked'].std()
mean_age = df['Embarked'].std()
df['Embarked'].fillna(random.randint(int(std_age),int(mean_age)), inplace=True)
# check if any more empty values in df
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# # Data Analysis and visualization

# %%
# Age vs survival

# the last ["EMbarked is just to take any of the count number"]
# less than 10 years old
y_1_m_s = df[(df["Age"]<10) & (df["Sex"]==0) & (df["Survived"]==1)]["Embarked"].count()
y_1_m_d = df[(df["Age"]<10) & (df["Sex"]==0) & (df["Survived"]==0)]["Embarked"].count()
y_1_f_s = df[(df["Age"]<10) & (df["Sex"]==1) & (df["Survived"]==1)]["Embarked"].count()
y_1_f_d = df[(df["Age"]<10) & (df["Sex"]==1) & (df["Survived"]==0)]["Embarked"].count()
# >= 10 y/o
y_2_m_s = df[(df["Age"]>=10) & (df["Age"]<20) & (df["Sex"]==0) & (df["Survived"]==1)]["Embarked"].count()
y_2_f_s = df[(df["Age"]>=10) & (df["Age"]<20) & (df["Sex"]==1) & (df["Survived"]==1)]["Embarked"].count()
y_2_m_d = df[(df["Age"]>=10) & (df["Age"]<20) & (df["Sex"]==0) & (df["Survived"]==0)]["Embarked"].count()
y_2_f_d = df[(df["Age"]>=10) & (df["Age"]<20) & (df["Sex"]==1) & (df["Survived"]==0)]["Embarked"].count()
# >= 20 y/o
y_3_m_s = df[(df["Age"]>=20) & (df["Age"]<30) & (df["Sex"]==0) & (df["Survived"]==1)]["Embarked"].count()
y_3_f_s = df[(df["Age"]>=20) & (df["Age"]<30) & (df["Sex"]==1) & (df["Survived"]==1)]["Embarked"].count()
y_3_m_d = df[(df["Age"]>=20) & (df["Age"]<30) & (df["Sex"]==0) & (df["Survived"]==0)]["Embarked"].count()
y_3_f_d = df[(df["Age"]>=20) & (df["Age"]<30) & (df["Sex"]==1) & (df["Survived"]==0)]["Embarked"].count()
# >= 30 y/o
y_4_m_s = df[(df["Age"]>=30) & (df["Age"]<40) & (df["Sex"]==0) & (df["Survived"]==1)]["Embarked"].count()
y_4_f_s = df[(df["Age"]>=30) & (df["Age"]<40) & (df["Sex"]==1) & (df["Survived"]==1)]["Embarked"].count()
y_4_m_d = df[(df["Age"]>=30) & (df["Age"]<40) & (df["Sex"]==0) & (df["Survived"]==0)]["Embarked"].count()
y_4_f_d = df[(df["Age"]>=30) & (df["Age"]<40) & (df["Sex"]==1) & (df["Survived"]==0)]["Embarked"].count()
# >= 40 y/o
y_5_m_s = df[(df["Age"]>=40) & (df["Age"]<50) & (df["Sex"]==0) & (df["Survived"]==1)]["Embarked"].count()
y_5_f_s = df[(df["Age"]>=40) & (df["Age"]<50) & (df["Sex"]==1) & (df["Survived"]==1)]["Embarked"].count()
y_5_m_d = df[(df["Age"]>=40) & (df["Age"]<50) & (df["Sex"]==0) & (df["Survived"]==0)]["Embarked"].count()
y_5_f_d = df[(df["Age"]>=40) & (df["Age"]<50) & (df["Sex"]==1) & (df["Survived"]==0)]["Embarked"].count()
# >= 50 y/o
y_6_m_s = df[(df["Age"]>=50) & (df["Age"]<60) & (df["Sex"]==0) & (df["Survived"]==1)]["Embarked"].count()
y_6_f_s = df[(df["Age"]>=50) & (df["Age"]<60) & (df["Sex"]==1) & (df["Survived"]==1)]["Embarked"].count()
y_6_m_d = df[(df["Age"]>=50) & (df["Age"]<60) & (df["Sex"]==0) & (df["Survived"]==0)]["Embarked"].count()
y_6_f_d = df[(df["Age"]>=50) & (df["Age"]<60) & (df["Sex"]==1) & (df["Survived"]==0)]["Embarked"].count()
# >= 60 y/o
y_7_m_s = df[(df["Age"]>=60) & (df["Age"]<70) & (df["Sex"]==0) & (df["Survived"]==1)]["Embarked"].count()
y_7_f_s = df[(df["Age"]>=60) & (df["Age"]<70) & (df["Sex"]==1) & (df["Survived"]==1)]["Embarked"].count()
y_7_m_d = df[(df["Age"]>=60) & (df["Age"]<70) & (df["Sex"]==0) & (df["Survived"]==0)]["Embarked"].count()
y_7_f_d = df[(df["Age"]>=60) & (df["Age"]<70) & (df["Sex"]==1) & (df["Survived"]==0)]["Embarked"].count()
# >= 70 y/o
y_8_m_s = df[(df["Age"]>=70) & (df["Sex"]==0) & (df["Survived"]==1)]["Embarked"].count()
y_8_f_s = df[(df["Age"]>=70) & (df["Sex"]==1) & (df["Survived"]==1)]["Embarked"].count()
y_8_m_d = df[(df["Age"]>=70) & (df["Sex"]==0) & (df["Survived"]==0)]["Embarked"].count()
y_8_f_d = df[(df["Age"]>=70) & (df["Sex"]==1) & (df["Survived"]==0)]["Embarked"].count()

men_survive = (y_1_m_s ,y_2_m_s ,y_3_m_s ,y_4_m_s, y_5_m_s, y_6_m_s ,y_7_m_s ,y_8_m_s )
women_survive = (y_1_f_s ,y_2_f_s ,y_3_f_s ,y_4_f_s, y_5_f_s, y_6_f_s ,y_7_f_s ,y_8_f_s )
men_no_survive = (y_1_m_d,y_2_m_d,y_3_m_d,y_4_m_d,y_5_m_d,y_6_m_d,y_7_m_d,y_8_m_d,)
women_no_survive = (y_1_f_d,y_2_f_d,y_3_f_d,y_4_f_d,y_5_f_d,y_6_f_d,y_7_f_d,y_8_f_d,)

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
n_groups = 8
fig, ax = plt.subplots(figsize=(10, 5))
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = ax.bar(index, men_survive, bar_width, bottom=None,
                alpha=opacity, color='#2db721',
                error_kw=error_config,
                label='Men Survive')
rects2 = ax.bar(index, women_survive, bar_width,bottom=None,
                alpha=opacity, color='#adaa1b',
                error_kw=error_config,
                label='women Survive')
rects3 = ax.bar(index+bar_width, men_no_survive, bar_width,bottom=None,
                alpha=opacity, color='#000000',
                error_kw=error_config,
                label="Men didn't make it")
rects4 = ax.bar(index+bar_width, women_no_survive, bar_width,bottom=None,
                alpha=opacity, color='r',
                error_kw=error_config,
                label="Women didn't make it")

ax.set_xlabel('Age Group')
ax.set_ylabel('Count')
ax.set_title('Count of Survival by age group and gender')
ax.set_xticks(index + bar_width/2)
ax.set_xticklabels(('<10', '>=10', '>=20', '>=30', '>=40', '>=50', '>=60', '>=70'),fontsize=12)
ax.legend()
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Social class vs Survival

# %%
# the last ["EMbarked is just to take any of the count number"]
social_1_s = df[(df['Pclass']==1) & (df['Survived']==1)]['Embarked'].count()
social_2_s = df[(df['Pclass']==2) & (df['Survived']==1)]['Embarked'].count()
social_3_s = df[(df['Pclass']==3) & (df['Survived']==1)]['Embarked'].count()
social_1_d = df[(df['Pclass']==1) & (df['Survived']==0)]['Embarked'].count()
social_2_d = df[(df['Pclass']==2) & (df['Survived']==0)]['Embarked'].count()
social_3_d = df[(df['Pclass']==3) & (df['Survived']==0)]['Embarked'].count()

# %%
n_groups = 3
fig, ax = plt.subplots(figsize=(10, 5))
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.4
error_config = {'ecolor': '0.3'}

a = (social_1_s,social_2_s,social_3_s)
b = (social_1_d,social_2_d,social_3_d)
rects1 = ax.bar(index, a, bar_width, bottom=None,
                alpha=opacity, color='#05821e',
                error_kw=error_config,
                label='Survive')
rects2 = ax.bar(index+bar_width,b, bar_width,bottom=None,
                alpha=opacity, color='#ba210d',
                error_kw=error_config,
                label="Didn't make it")

ax.set_xlabel('Social Class')
ax.set_ylabel('Count')
ax.set_title('Count of Survival by social class')
ax.set_xticks(index + bar_width/2)
ax.set_xticklabels(('Upper class','Middle class','Lower class'),fontsize=12)
ax.legend()
fig.tight_layout()
plt.show()

# %% [markdown]
# # Time to train our AI Models
#
# ================================================================
#
# ================================================================
#
# ================================================================
#
# ================================================================
#
# ================================================================

# %% [markdown]
# Preparing the training data

# %%
x = df.drop(["Survived"],axis=1)
y = df["Survived"]

# The below is used to split a df into test and train sets.
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.25, random_state=27)

# %%
def train_model(x_train,y_train,layer_shape,optimizer):
    # layer shape is in a python list [20,20,20]
    #solver options => solver : {‘lbfgs’, ‘sgd’, ‘adam’}, default ‘adam’
    model = MLPClassifier(hidden_layer_sizes=(layer_shape), max_iter=6000, alpha=0.000000001,
                         solver=optimizer, verbose=False,random_state=21,tol=0.000000001,learning_rate="adaptive")
    model.fit(x_train, y_train)
    return model

# %%
#optimizer options => solver : {‘lbfgs’, ‘sgd’, ‘adam’}, default ‘adam’ for MLPClassifier and regressor
optimizer = 'adam'
layer_shape = [20,20]
model = train_model(x_train,y_train,layer_shape,optimizer)
y_pred = model.predict(x_test)

# %% [markdown]
# Check accuracy of model

# %%
## accuracy_score(y_true, y_pred, normalize=True, sample_weight=None)
accuracy_score(y_test,y_pred)
# Out:
# 0.8026905829596412

# %% [markdown]
# ### Optimizing for a better accuracy
# We can then try to increase put accuracy by playing around with the neural network
#
# try
#
# 20 x 20 x 20
# or any other cominations of layer sizes

# %%
def accuracy_optimizer(x_train,y_train,layer_shapes_to_test,optimizer,verbose=False):
    print("Finding Best accuracy layer shape")
    max_acc = 0
    for i,layer_shape in enumerate(layer_shapes_to_test):
        layer_shape = layer_shape
        model = train_model(x_train,y_train,layer_shape,optimizer)
        y_pred = model.predict(x_test)
        ## accuracy_score(y_true, y_pred, normalize=True, sample_weight=None)
        accuracy = accuracy_score(y_test,y_pred)
        if verbose == True:
            print("The Hidden Layer shape",layer_shape,"has accuracy of",accuracy)
        if i==0:
            max_acc = accuracy
            max_acc_shape = layer_shape
        elif accuracy > max_acc:
            max_acc = accuracy
            max_acc_shape = layer_shape
    print(max_acc,max_acc_shape)
    f = open("max_accuracy.txt", "w")
    write_str = str(max_acc)+ ":::" +str(max_acc_shape)
    f.write(write_str)
    

#layer_shapes_to_test = [[20],[20,20],[10],[10,10]]
layer_shapes_to_test = []
for i in range(20,41):
    for j in range(20,41):
        layer_shapes_to_test.append([i,j])
accuracy_optimizer(x_train,y_train,layer_shapes_to_test,optimizer,True)
# Out:
# [[20, 20], [20, 21], [20, 22], [20, 23], [20, 24], [20, 25], [20, 26], [20, 27], [20, 28], [20, 29], [20, 30], [20, 31], [20, 32], [20, 33], [20, 34], [20, 35], [20, 36], [20, 37], [20, 38], [20, 39], [20, 40], [21, 20], [21, 21], [21, 22], [21, 23], [21, 24], [21, 25], [21, 26], [21, 27], [21, 28], [21, 29], [21, 30], [21, 31], [21, 32], [21, 33], [21, 34], [21, 35], [21, 36], [21, 37], [21, 38], [21, 39], [21, 40], [22, 20], [22, 21], [22, 22], [22, 23], [22, 24], [22, 25], [22, 26], [22, 27], [22, 28], [22, 29], [22, 30], [22, 31], [22, 32], [22, 33], [22, 34], [22, 35], [22, 36], [22, 37], [22, 38], [22, 39], [22, 40], [23, 20], [23, 21], [23, 22], [23, 23], [23, 24], [23, 25], [23, 26], [23, 27], [23, 28], [23, 29], [23, 30], [23, 31], [23, 32], [23, 33], [23, 34], [23, 35], [23, 36], [23, 37], [23, 38], [23, 39], [23, 40], [24, 20], [24, 21], [24, 22], [24, 23], [24, 24], [24, 25], [24, 26], [24, 27], [24, 28], [24, 29], [24, 30], [24, 31], [24, 32], [24, 33], [24, 34], [24, 35], [24, 36], [24, 37], [24, 38], [24, 39], [24, 40], [25, 20], [25, 21], [25, 22], [25, 23], [25, 24], [25, 25], [25, 26], [25, 27], [25, 28], [25, 29], [25, 30], [25, 31], [25, 32], [25, 33], [25, 34], [25, 35], [25, 36], [25, 37], [25, 38], [25, 39], [25, 40], [26, 20], [26, 21], [26, 22], [26, 23], [26, 24], [26, 25], [26, 26], [26, 27], [26, 28], [26, 29], [26, 30], [26, 31], [26, 32], [26, 33], [26, 34], [26, 35], [26, 36], [26, 37], [26, 38], [26, 39], [26, 40], [27, 20], [27, 21], [27, 22], [27, 23], [27, 24], [27, 25], [27, 26], [27, 27], [27, 28], [27, 29], [27, 30], [27, 31], [27, 32], [27, 33], [27, 34], [27, 35], [27, 36], [27, 37], [27, 38], [27, 39], [27, 40], [28, 20], [28, 21], [28, 22], [28, 23], [28, 24], [28, 25], [28, 26], [28, 27], [28, 28], [28, 29], [28, 30], [28, 31], [28, 32], [28, 33], [28, 34], [28, 35], [28, 36], [28, 37], [28, 38], [28, 39], [28, 40], [29, 20], [29, 21], [29, 22], [29, 23], [29, 24], [29, 25], [29, 26], [29, 27], [29, 28], [29, 29], [29, 30], [29, 31], [29, 32], [29, 33], [29, 34], [29, 35], [29, 36], [29, 37], [29, 38], [29, 39], [29, 40], [30, 20], [30, 21], [30, 22], [30, 23], [30, 24], [30, 25], [30, 26], [30, 27], [30, 28], [30, 29], [30, 30], [30, 31], [30, 32], [30, 33], [30, 34], [30, 35], [30, 36], [30, 37], [30, 38], [30, 39], [30, 40], [31, 20], [31, 21], [31, 22], [31, 23], [31, 24], [31, 25], [31, 26], [31, 27], [31, 28], [31, 29], [31, 30], [31, 31], [31, 32], [31, 33], [31, 34], [31, 35], [31, 36], [31, 37], [31, 38], [31, 39], [31, 40], [32, 20], [32, 21], [32, 22], [32, 23], [32, 24], [32, 25], [32, 26], [32, 27], [32, 28], [32, 29], [32, 30], [32, 31], [32, 32], [32, 33], [32, 34], [32, 35], [32, 36], [32, 37], [32, 38], [32, 39], [32, 40], [33, 20], [33, 21], [33, 22], [33, 23], [33, 24], [33, 25], [33, 26], [33, 27], [33, 28], [33, 29], [33, 30], [33, 31], [33, 32], [33, 33], [33, 34], [33, 35], [33, 36], [33, 37], [33, 38], [33, 39], [33, 40], [34, 20], [34, 21], [34, 22], [34, 23], [34, 24], [34, 25], [34, 26], [34, 27], [34, 28], [34, 29], [34, 30], [34, 31], [34, 32], [34, 33], [34, 34], [34, 35], [34, 36], [34, 37], [34, 38], [34, 39], [34, 40], [35, 20], [35, 21], [35, 22], [35, 23], [35, 24], [35, 25], [35, 26], [35, 27], [35, 28], [35, 29], [35, 30], [35, 31], [35, 32], [35, 33], [35, 34], [35, 35], [35, 36], [35, 37], [35, 38], [35, 39], [35, 40], [36, 20], [36, 21], [36, 22], [36, 23], [36, 24], [36, 25], [36, 26], [36, 27], [36, 28], [36, 29], [36, 30], [36, 31], [36, 32], [36, 33], [36, 34], [36, 35], [36, 36], [36, 37], [36, 38], [36, 39], [36, 40], [37, 20], [37, 21], [37, 22], [37, 23], [37, 24], [37, 25], [37, 26], [37, 27], [37, 28], [37, 29], [37, 30], [37, 31], [37, 32], [37, 33], [37, 34], [37, 35], [37, 36], [37, 37], [37, 38], [37, 39], [37, 40], [38, 20], [38, 21], [38, 22], [38, 23], [38, 24], [38, 25], [38, 26], [38, 27], [38, 28], [38, 29], [38, 30], [38, 31], [38, 32], [38, 33], [38, 34], [38, 35], [38, 36], [38, 37], [38, 38], [38, 39], [38, 40], [39, 20], ...
# Finding Best accuracy layer shape
# The Hidden Layer shape [20, 20] has accuracy of 0.8026905829596412
# The Hidden Layer shape [20, 21] has accuracy of 0.7623318385650224
# The Hidden Layer shape [20, 22] has accuracy of 0.7399103139013453
# The Hidden Layer shape [20, 23] has accuracy of 0.757847533632287
# The Hidden Layer shape [20, 24] has accuracy of 0.7488789237668162
# The Hidden Layer shape [20, 25] has accuracy of 0.7668161434977578
# The Hidden Layer shape [20, 26] has accuracy of 0.7533632286995515
# The Hidden Layer shape [20, 27] has accuracy of 0.757847533632287
# The Hidden Layer shape [20, 28] has accuracy of 0.7668161434977578
# The Hidden Layer shape [20, 29] has accuracy of 0.7802690582959642
# The Hidden Layer shape [20, 30] has accuracy of 0.7623318385650224
# The Hidden Layer shape [20, 31] has accuracy of 0.7713004484304933
# The Hidden Layer shape [20, 32] has accuracy of 0.7668161434977578
# The Hidden Layer shape [20, 33] has accuracy of 0.7399103139013453
# The Hidden Layer shape [20, 34] has accuracy of 0.7713004484304933
# The Hidden Layer shape [20, 35] has accuracy of 0.7443946188340808
# The Hidden Layer shape [20, 36] has accuracy of 0.7937219730941704
# The Hidden Layer shape [20, 37] has accuracy of 0.757847533632287
# The Hidden Layer shape [20, 38] has accuracy of 0.7668161434977578
# The Hidden Layer shape [20, 39] has accuracy of 0.7713004484304933
# The Hidden Layer shape [20, 40] has accuracy of 0.7892376681614349
# The Hidden Layer shape [21, 20] has accuracy of 0.7668161434977578
# The Hidden Layer shape [21, 21] has accuracy of 0.7713004484304933
# The Hidden Layer shape [21, 22] has accuracy of 0.7713004484304933
# The Hidden Layer shape [21, 23] has accuracy of 0.7713004484304933
# The Hidden Layer shape [21, 24] has accuracy of 0.7668161434977578
# The Hidden Layer shape [21, 25] has accuracy of 0.7847533632286996
# The Hidden Layer shape [21, 26] has accuracy of 0.7713004484304933
# The Hidden Layer shape [21, 27] has accuracy of 0.7623318385650224
# The Hidden Layer shape [21, 28] has accuracy of 0.7757847533632287
# The Hidden Layer shape [21, 29] has accuracy of 0.757847533632287
# The Hidden Layer shape [21, 30] has accuracy of 0.7713004484304933
# The Hidden Layer shape [21, 31] has accuracy of 0.7802690582959642
# The Hidden Layer shape [21, 32] has accuracy of 0.7802690582959642
# The Hidden Layer shape [21, 33] has accuracy of 0.7623318385650224
# The Hidden Layer shape [21, 34] has accuracy of 0.7802690582959642
# The Hidden Layer shape [21, 35] has accuracy of 0.7713004484304933
# The Hidden Layer shape [21, 36] has accuracy of 0.7802690582959642
# The Hidden Layer shape [21, 37] has accuracy of 0.7757847533632287
# The Hidden Layer shape [21, 38] has accuracy of 0.8026905829596412
# The Hidden Layer shape [21, 39] has accuracy of 0.757847533632287
# The Hidden Layer shape [21, 40] has accuracy of 0.7757847533632287
# The Hidden Layer shape [22, 20] has accuracy of 0.7668161434977578
# The Hidden Layer shape [22, 21] has accuracy of 0.7802690582959642
# The Hidden Layer shape [22, 22] has accuracy of 0.7802690582959642
# The Hidden Layer shape [22, 23] has accuracy of 0.7982062780269058
# The Hidden Layer shape [22, 24] has accuracy of 0.7937219730941704
# The Hidden Layer shape [22, 25] has accuracy of 0.7757847533632287
# The Hidden Layer shape [22, 26] has accuracy of 0.7802690582959642
# The Hidden Layer shape [22, 27] has accuracy of 0.757847533632287
# The Hidden Layer shape [22, 28] has accuracy of 0.7623318385650224
# The Hidden Layer shape [22, 29] has accuracy of 0.8071748878923767
# The Hidden Layer shape [22, 30] has accuracy of 0.7623318385650224
# The Hidden Layer shape [22, 31] has accuracy of 0.7757847533632287
# The Hidden Layer shape [22, 32] has accuracy of 0.7802690582959642
# The Hidden Layer shape [22, 33] has accuracy of 0.7982062780269058
# The Hidden Layer shape [22, 34] has accuracy of 0.7757847533632287
# The Hidden Layer shape [22, 35] has accuracy of 0.7757847533632287
# The Hidden Layer shape [22, 36] has accuracy of 0.7802690582959642
# The Hidden Layer shape [22, 37] has accuracy of 0.7668161434977578
# The Hidden Layer shape [22, 38] has accuracy of 0.7757847533632287
# The Hidden Layer shape [22, 39] has accuracy of 0.7713004484304933
# The Hidden Layer shape [22, 40] has accuracy of 0.7713004484304933
# The Hidden Layer shape [23, 20] has accuracy of 0.7713004484304933
# The Hidden Layer shape [23, 21] has accuracy of 0.7802690582959642
# The Hidden Layer shape [23, 22] has accuracy of 0.7757847533632287
# The Hidden Layer shape [23, 23] has accuracy of 0.7533632286995515
# The Hidden Layer shape [23, 24] has accuracy of 0.7757847533632287
# The Hidden Layer shape [23, 25] has accuracy of 0.7668161434977578
# The Hidden Layer shape [23, 26] has accuracy of 0.7802690582959642
# The Hidden Layer shape [23, 27] has accuracy of 0.7892376681614349
# The Hidden Layer shape [23, 28] has accuracy of 0.7892376681614349
# The Hidden Layer shape [23, 29] has accuracy of 0.7937219730941704
# The Hidden Layer shape [23, 30] has accuracy of 0.7623318385650224
# The Hidden Layer shape [23, 31] has accuracy of 0.7892376681614349
# The Hidden Layer shape [23, 32] has accuracy of 0.7802690582959642
# The Hidden Layer shape [23, 33] has accuracy of 0.7802690582959642
# The Hidden Layer shape [23, 34] has accuracy of 0.7757847533632287
# The Hidden Layer shape [23, 35] has accuracy of 0.7533632286995515
# The Hidden Layer shape [23, 36] has accuracy of 0.7623318385650224
# The Hidden Layer shape [23, 37] has accuracy of 0.7937219730941704
# The Hidden Layer shape [23, 38] has accuracy of 0.7802690582959642
# The Hidden Layer shape [23, 39] has accuracy of 0.7757847533632287
# The Hidden Layer shape [23, 40] has accuracy of 0.7802690582959642
# The Hidden Layer shape [24, 20] has accuracy of 0.7668161434977578
# The Hidden Layer shape [24, 21] has accuracy of 0.7533632286995515
# The Hidden Layer shape [24, 22] has accuracy of 0.7668161434977578
# The Hidden Layer shape [24, 23] has accuracy of 0.7623318385650224
# The Hidden Layer shape [24, 24] has accuracy of 0.7533632286995515
# The Hidden Layer shape [24, 25] has accuracy of 0.757847533632287
# The Hidden Layer shape [24, 26] has accuracy of 0.757847533632287
# The Hidden Layer shape [24, 27] has accuracy of 0.7354260089686099
# The Hidden Layer shape [24, 28] has accuracy of 0.7713004484304933
# The Hidden Layer shape [24, 29] has accuracy of 0.7668161434977578
# The Hidden Layer shape [24, 30] has accuracy of 0.7668161434977578
# The Hidden Layer shape [24, 31] has accuracy of 0.7847533632286996
# The Hidden Layer shape [24, 32] has accuracy of 0.7623318385650224
# The Hidden Layer shape [24, 33] has accuracy of 0.7668161434977578
# The Hidden Layer shape [24, 34] has accuracy of 0.7713004484304933
# The Hidden Layer shape [24, 35] has accuracy of 0.7668161434977578
# The Hidden Layer shape [24, 36] has accuracy of 0.7802690582959642
# The Hidden Layer shape [24, 37] has accuracy of 0.7623318385650224
# The Hidden Layer shape [24, 38] has accuracy of 0.7757847533632287
# The Hidden Layer shape [24, 39] has accuracy of 0.7488789237668162
# The Hidden Layer shape [24, 40] has accuracy of 0.7802690582959642
# The Hidden Layer shape [25, 20] has accuracy of 0.7713004484304933
# The Hidden Layer shape [25, 21] has accuracy of 0.7713004484304933
# The Hidden Layer shape [25, 22] has accuracy of 0.7668161434977578
# The Hidden Layer shape [25, 23] has accuracy of 0.7668161434977578
# The Hidden Layer shape [25, 24] has accuracy of 0.7802690582959642
# The Hidden Layer shape [25, 25] has accuracy of 0.7533632286995515
# The Hidden Layer shape [25, 26] has accuracy of 0.7892376681614349
# The Hidden Layer shape [25, 27] has accuracy of 0.7668161434977578
# The Hidden Layer shape [25, 28] has accuracy of 0.7623318385650224
# The Hidden Layer shape [25, 29] has accuracy of 0.7802690582959642
# The Hidden Layer shape [25, 30] has accuracy of 0.7713004484304933
# The Hidden Layer shape [25, 31] has accuracy of 0.7802690582959642
# The Hidden Layer shape [25, 32] has accuracy of 0.7802690582959642
# The Hidden Layer shape [25, 33] has accuracy of 0.7488789237668162
# The Hidden Layer shape [25, 34] has accuracy of 0.757847533632287
# The Hidden Layer shape [25, 35] has accuracy of 0.7757847533632287
# The Hidden Layer shape [25, 36] has accuracy of 0.7802690582959642
# The Hidden Layer shape [25, 37] has accuracy of 0.7802690582959642
# The Hidden Layer shape [25, 38] has accuracy of 0.7623318385650224
# The Hidden Layer shape [25, 39] has accuracy of 0.7802690582959642
# The Hidden Layer shape [25, 40] has accuracy of 0.7623318385650224
# The Hidden Layer shape [26, 20] has accuracy of 0.7623318385650224
# The Hidden Layer shape [26, 21] has accuracy of 0.7533632286995515
# The Hidden Layer shape [26, 22] has accuracy of 0.7623318385650224
# The Hidden Layer shape [26, 23] has accuracy of 0.7623318385650224
# The Hidden Layer shape [26, 24] has accuracy of 0.7668161434977578
# The Hidden Layer shape [26, 25] has accuracy of 0.7713004484304933
# The Hidden Layer shape [26, 26] has accuracy of 0.7623318385650224
# The Hidden Layer shape [26, 27] has accuracy of 0.7802690582959642
# The Hidden Layer shape [26, 28] has accuracy of 0.7623318385650224
# The Hidden Layer shape [26, 29] has accuracy of 0.7668161434977578
# The Hidden Layer shape [26, 30] has accuracy of 0.7668161434977578
# The Hidden Layer shape [26, 31] has accuracy of 0.7713004484304933
# The Hidden Layer shape [26, 32] has accuracy of 0.7802690582959642
# The Hidden Layer shape [26, 33] has accuracy of 0.7757847533632287
# The Hidden Layer shape [26, 34] has accuracy of 0.757847533632287
# The Hidden Layer shape [26, 35] has accuracy of 0.7757847533632287
# The Hidden Layer shape [26, 36] has accuracy of 0.7802690582959642
# The Hidden Layer shape [26, 37] has accuracy of 0.7623318385650224
# The Hidden Layer shape [26, 38] has accuracy of 0.7623318385650224
# The Hidden Layer shape [26, 39] has accuracy of 0.7713004484304933
# The Hidden Layer shape [26, 40] has accuracy of 0.7802690582959642
# The Hidden Layer shape [27, 20] has accuracy of 0.7757847533632287
# The Hidden Layer shape [27, 21] has accuracy of 0.7757847533632287
# The Hidden Layer shape [27, 22] has accuracy of 0.7488789237668162
# The Hidden Layer shape [27, 23] has accuracy of 0.7533632286995515
# The Hidden Layer shape [27, 24] has accuracy of 0.7713004484304933
# The Hidden Layer shape [27, 25] has accuracy of 0.7668161434977578
# The Hidden Layer shape [27, 26] has accuracy of 0.7802690582959642
# The Hidden Layer shape [27, 27] has accuracy of 0.7757847533632287
# The Hidden Layer shape [27, 28] has accuracy of 0.7533632286995515
# The Hidden Layer shape [27, 29] has accuracy of 0.7937219730941704
# The Hidden Layer shape [27, 30] has accuracy of 0.7847533632286996
# The Hidden Layer shape [27, 31] has accuracy of 0.7982062780269058
# The Hidden Layer shape [27, 32] has accuracy of 0.7713004484304933
# The Hidden Layer shape [27, 33] has accuracy of 0.7533632286995515
# The Hidden Layer shape [27, 34] has accuracy of 0.7937219730941704
# The Hidden Layer shape [27, 35] has accuracy of 0.7668161434977578
# The Hidden Layer shape [27, 36] has accuracy of 0.7982062780269058
# The Hidden Layer shape [27, 37] has accuracy of 0.7802690582959642
# The Hidden Layer shape [27, 38] has accuracy of 0.7757847533632287
# The Hidden Layer shape [27, 39] has accuracy of 0.7488789237668162
# The Hidden Layer shape [27, 40] has accuracy of 0.7713004484304933
# The Hidden Layer shape [28, 20] has accuracy of 0.7668161434977578
# The Hidden Layer shape [28, 21] has accuracy of 0.757847533632287
# The Hidden Layer shape [28, 22] has accuracy of 0.7713004484304933
# The Hidden Layer shape [28, 23] has accuracy of 0.7713004484304933
# The Hidden Layer shape [28, 24] has accuracy of 0.7623318385650224
# The Hidden Layer shape [28, 25] has accuracy of 0.7713004484304933
# The Hidden Layer shape [28, 26] has accuracy of 0.7668161434977578
# The Hidden Layer shape [28, 27] has accuracy of 0.7892376681614349
# The Hidden Layer shape [28, 28] has accuracy of 0.7757847533632287
# The Hidden Layer shape [28, 29] has accuracy of 0.7802690582959642
# The Hidden Layer shape [28, 30] has accuracy of 0.7802690582959642
# The Hidden Layer shape [28, 31] has accuracy of 0.7668161434977578
# The Hidden Layer shape [28, 32] has accuracy of 0.7892376681614349
# The Hidden Layer shape [28, 33] has accuracy of 0.8026905829596412
# The Hidden Layer shape [28, 34] has accuracy of 0.7713004484304933
# The Hidden Layer shape [28, 35] has accuracy of 0.7802690582959642
# The Hidden Layer shape [28, 36] has accuracy of 0.7533632286995515
# The Hidden Layer shape [28, 37] has accuracy of 0.7847533632286996
# The Hidden Layer shape [28, 38] has accuracy of 0.7847533632286996
# The Hidden Layer shape [28, 39] has accuracy of 0.757847533632287
# The Hidden Layer shape [28, 40] has accuracy of 0.7847533632286996
# The Hidden Layer shape [29, 20] has accuracy of 0.7847533632286996
# The Hidden Layer shape [29, 21] has accuracy of 0.7802690582959642
# The Hidden Layer shape [29, 22] has accuracy of 0.7668161434977578
# The Hidden Layer shape [29, 23] has accuracy of 0.7757847533632287
# The Hidden Layer shape [29, 24] has accuracy of 0.7757847533632287
# The Hidden Layer shape [29, 25] has accuracy of 0.7533632286995515
# The Hidden Layer shape [29, 26] has accuracy of 0.7937219730941704
# The Hidden Layer shape [29, 27] has accuracy of 0.7847533632286996
# The Hidden Layer shape [29, 28] has accuracy of 0.7713004484304933
# The Hidden Layer shape [29, 29] has accuracy of 0.7892376681614349
# The Hidden Layer shape [29, 30] has accuracy of 0.7982062780269058
# The Hidden Layer shape [29, 31] has accuracy of 0.7533632286995515
# The Hidden Layer shape [29, 32] has accuracy of 0.7757847533632287
# The Hidden Layer shape [29, 33] has accuracy of 0.7623318385650224
# The Hidden Layer shape [29, 34] has accuracy of 0.7757847533632287
# The Hidden Layer shape [29, 35] has accuracy of 0.7847533632286996
# The Hidden Layer shape [29, 36] has accuracy of 0.7847533632286996
# The Hidden Layer shape [29, 37] has accuracy of 0.7757847533632287
# The Hidden Layer shape [29, 38] has accuracy of 0.7668161434977578
# The Hidden Layer shape [29, 39] has accuracy of 0.7668161434977578
# The Hidden Layer shape [29, 40] has accuracy of 0.7623318385650224
# The Hidden Layer shape [30, 20] has accuracy of 0.7713004484304933
# The Hidden Layer shape [30, 21] has accuracy of 0.7668161434977578
# The Hidden Layer shape [30, 22] has accuracy of 0.7757847533632287
# The Hidden Layer shape [30, 23] has accuracy of 0.757847533632287
# The Hidden Layer shape [30, 24] has accuracy of 0.7757847533632287
# The Hidden Layer shape [30, 25] has accuracy of 0.7892376681614349
# The Hidden Layer shape [30, 26] has accuracy of 0.7533632286995515
# The Hidden Layer shape [30, 27] has accuracy of 0.7757847533632287
# The Hidden Layer shape [30, 28] has accuracy of 0.7757847533632287
# The Hidden Layer shape [30, 29] has accuracy of 0.757847533632287
# The Hidden Layer shape [30, 30] has accuracy of 0.7713004484304933
# The Hidden Layer shape [30, 31] has accuracy of 0.7892376681614349
# The Hidden Layer shape [30, 32] has accuracy of 0.7713004484304933
# The Hidden Layer shape [30, 33] has accuracy of 0.7847533632286996
# The Hidden Layer shape [30, 34] has accuracy of 0.7668161434977578
# The Hidden Layer shape [30, 35] has accuracy of 0.7892376681614349
# The Hidden Layer shape [30, 36] has accuracy of 0.7623318385650224
# The Hidden Layer shape [30, 37] has accuracy of 0.757847533632287
# The Hidden Layer shape [30, 38] has accuracy of 0.7757847533632287
# The Hidden Layer shape [30, 39] has accuracy of 0.7668161434977578
# The Hidden Layer shape [30, 40] has accuracy of 0.7668161434977578
# The Hidden Layer shape [31, 20] has accuracy of 0.7713004484304933
# The Hidden Layer shape [31, 21] has accuracy of 0.757847533632287
# The Hidden Layer shape [31, 22] has accuracy of 0.7757847533632287
# The Hidden Layer shape [31, 23] has accuracy of 0.757847533632287
# The Hidden Layer shape [31, 24] has accuracy of 0.7713004484304933
# The Hidden Layer shape [31, 25] has accuracy of 0.7533632286995515
# The Hidden Layer shape [31, 26] has accuracy of 0.7892376681614349
# The Hidden Layer shape [31, 27] has accuracy of 0.7937219730941704
# The Hidden Layer shape [31, 28] has accuracy of 0.7668161434977578
# The Hidden Layer shape [31, 29] has accuracy of 0.8071748878923767
# The Hidden Layer shape [31, 30] has accuracy of 0.7937219730941704
# The Hidden Layer shape [31, 31] has accuracy of 0.7713004484304933
# The Hidden Layer shape [31, 32] has accuracy of 0.7847533632286996
# The Hidden Layer shape [31, 33] has accuracy of 0.8071748878923767
# The Hidden Layer shape [31, 34] has accuracy of 0.7623318385650224
# The Hidden Layer shape [31, 35] has accuracy of 0.7757847533632287
# The Hidden Layer shape [31, 36] has accuracy of 0.7892376681614349
# The Hidden Layer shape [31, 37] has accuracy of 0.7982062780269058
# The Hidden Layer shape [31, 38] has accuracy of 0.8071748878923767
# The Hidden Layer shape [31, 39] has accuracy of 0.7757847533632287
# The Hidden Layer shape [31, 40] has accuracy of 0.7623318385650224
# The Hidden Layer shape [32, 20] has accuracy of 0.7982062780269058
# The Hidden Layer shape [32, 21] has accuracy of 0.7937219730941704
# The Hidden Layer shape [32, 22] has accuracy of 0.7488789237668162
# The Hidden Layer shape [32, 23] has accuracy of 0.7668161434977578
# The Hidden Layer shape [32, 24] has accuracy of 0.7802690582959642
# The Hidden Layer shape [32, 25] has accuracy of 0.7847533632286996
# The Hidden Layer shape [32, 26] has accuracy of 0.7668161434977578
# The Hidden Layer shape [32, 27] has accuracy of 0.7668161434977578
# The Hidden Layer shape [32, 28] has accuracy of 0.7668161434977578
# The Hidden Layer shape [32, 29] has accuracy of 0.7937219730941704
# The Hidden Layer shape [32, 30] has accuracy of 0.7713004484304933
# The Hidden Layer shape [32, 31] has accuracy of 0.7892376681614349
# The Hidden Layer shape [32, 32] has accuracy of 0.7802690582959642
# The Hidden Layer shape [32, 33] has accuracy of 0.7533632286995515
# The Hidden Layer shape [32, 34] has accuracy of 0.7713004484304933
# The Hidden Layer shape [32, 35] has accuracy of 0.7892376681614349
# The Hidden Layer shape [32, 36] has accuracy of 0.7847533632286996
# The Hidden Layer shape [32, 37] has accuracy of 0.7937219730941704
# The Hidden Layer shape [32, 38] has accuracy of 0.7623318385650224
# The Hidden Layer shape [32, 39] has accuracy of 0.7847533632286996
# The Hidden Layer shape [32, 40] has accuracy of 0.7533632286995515
# The Hidden Layer shape [33, 20] has accuracy of 0.7802690582959642
# The Hidden Layer shape [33, 21] has accuracy of 0.7713004484304933
# The Hidden Layer shape [33, 22] has accuracy of 0.7982062780269058
# The Hidden Layer shape [33, 23] has accuracy of 0.7757847533632287
# The Hidden Layer shape [33, 24] has accuracy of 0.757847533632287
# The Hidden Layer shape [33, 25] has accuracy of 0.7713004484304933
# The Hidden Layer shape [33, 26] has accuracy of 0.7892376681614349
# The Hidden Layer shape [33, 27] has accuracy of 0.757847533632287
# The Hidden Layer shape [33, 28] has accuracy of 0.7937219730941704
# The Hidden Layer shape [33, 29] has accuracy of 0.7802690582959642
# The Hidden Layer shape [33, 30] has accuracy of 0.7623318385650224
# The Hidden Layer shape [33, 31] has accuracy of 0.7802690582959642
# The Hidden Layer shape [33, 32] has accuracy of 0.7892376681614349
# The Hidden Layer shape [33, 33] has accuracy of 0.7757847533632287
# The Hidden Layer shape [33, 34] has accuracy of 0.7847533632286996
# The Hidden Layer shape [33, 35] has accuracy of 0.757847533632287
# The Hidden Layer shape [33, 36] has accuracy of 0.7757847533632287
# The Hidden Layer shape [33, 37] has accuracy of 0.8161434977578476
# The Hidden Layer shape [33, 38] has accuracy of 0.7757847533632287
# The Hidden Layer shape [33, 39] has accuracy of 0.757847533632287
# The Hidden Layer shape [33, 40] has accuracy of 0.7802690582959642
# The Hidden Layer shape [34, 20] has accuracy of 0.7937219730941704
# The Hidden Layer shape [34, 21] has accuracy of 0.7668161434977578
# The Hidden Layer shape [34, 22] has accuracy of 0.7802690582959642
# The Hidden Layer shape [34, 23] has accuracy of 0.7892376681614349
# The Hidden Layer shape [34, 24] has accuracy of 0.7668161434977578
# The Hidden Layer shape [34, 25] has accuracy of 0.7713004484304933
# The Hidden Layer shape [34, 26] has accuracy of 0.7623318385650224
# The Hidden Layer shape [34, 27] has accuracy of 0.7802690582959642
# The Hidden Layer shape [34, 28] has accuracy of 0.7847533632286996
# The Hidden Layer shape [34, 29] has accuracy of 0.7892376681614349
# The Hidden Layer shape [34, 30] has accuracy of 0.7757847533632287
# The Hidden Layer shape [34, 31] has accuracy of 0.7802690582959642
# The Hidden Layer shape [34, 32] has accuracy of 0.7937219730941704
# The Hidden Layer shape [34, 33] has accuracy of 0.7668161434977578
# The Hidden Layer shape [34, 34] has accuracy of 0.7713004484304933
# The Hidden Layer shape [34, 35] has accuracy of 0.7847533632286996
# The Hidden Layer shape [34, 36] has accuracy of 0.7399103139013453
# The Hidden Layer shape [34, 37] has accuracy of 0.7623318385650224
# The Hidden Layer shape [34, 38] has accuracy of 0.7713004484304933
# The Hidden Layer shape [34, 39] has accuracy of 0.8026905829596412
# The Hidden Layer shape [34, 40] has accuracy of 0.7713004484304933
# The Hidden Layer shape [35, 20] has accuracy of 0.7668161434977578
# The Hidden Layer shape [35, 21] has accuracy of 0.7892376681614349
# The Hidden Layer shape [35, 22] has accuracy of 0.7802690582959642
# The Hidden Layer shape [35, 23] has accuracy of 0.7892376681614349
# The Hidden Layer shape [35, 24] has accuracy of 0.7802690582959642
# The Hidden Layer shape [35, 25] has accuracy of 0.7937219730941704
# The Hidden Layer shape [35, 26] has accuracy of 0.7937219730941704
# The Hidden Layer shape [35, 27] has accuracy of 0.7937219730941704
# The Hidden Layer shape [35, 28] has accuracy of 0.7892376681614349
# The Hidden Layer shape [35, 29] has accuracy of 0.7713004484304933
# The Hidden Layer shape [35, 30] has accuracy of 0.757847533632287
# The Hidden Layer shape [35, 31] has accuracy of 0.7802690582959642
# The Hidden Layer shape [35, 32] has accuracy of 0.8116591928251121
# The Hidden Layer shape [35, 33] has accuracy of 0.7713004484304933
# The Hidden Layer shape [35, 34] has accuracy of 0.7623318385650224
# The Hidden Layer shape [35, 35] has accuracy of 0.7757847533632287
# The Hidden Layer shape [35, 36] has accuracy of 0.7623318385650224
# The Hidden Layer shape [35, 37] has accuracy of 0.7757847533632287
# The Hidden Layer shape [35, 38] has accuracy of 0.8026905829596412
# The Hidden Layer shape [35, 39] has accuracy of 0.7892376681614349
# The Hidden Layer shape [35, 40] has accuracy of 0.757847533632287
# The Hidden Layer shape [36, 20] has accuracy of 0.8071748878923767
# The Hidden Layer shape [36, 21] has accuracy of 0.7757847533632287
# The Hidden Layer shape [36, 22] has accuracy of 0.7802690582959642
# The Hidden Layer shape [36, 23] has accuracy of 0.7937219730941704
# The Hidden Layer shape [36, 24] has accuracy of 0.7668161434977578
# The Hidden Layer shape [36, 25] has accuracy of 0.7757847533632287
# The Hidden Layer shape [36, 26] has accuracy of 0.7937219730941704
# The Hidden Layer shape [36, 27] has accuracy of 0.8071748878923767
# The Hidden Layer shape [36, 28] has accuracy of 0.7982062780269058
# The Hidden Layer shape [36, 29] has accuracy of 0.7847533632286996
# The Hidden Layer shape [36, 30] has accuracy of 0.7668161434977578
# The Hidden Layer shape [36, 31] has accuracy of 0.7847533632286996
# The Hidden Layer shape [36, 32] has accuracy of 0.7802690582959642
# The Hidden Layer shape [36, 33] has accuracy of 0.7892376681614349
# The Hidden Layer shape [36, 34] has accuracy of 0.7892376681614349
# The Hidden Layer shape [36, 35] has accuracy of 0.7802690582959642
# The Hidden Layer shape [36, 36] has accuracy of 0.7757847533632287
# The Hidden Layer shape [36, 37] has accuracy of 0.7892376681614349
# The Hidden Layer shape [36, 38] has accuracy of 0.7847533632286996
# The Hidden Layer shape [36, 39] has accuracy of 0.7892376681614349
# The Hidden Layer shape [36, 40] has accuracy of 0.7937219730941704
# The Hidden Layer shape [37, 20] has accuracy of 0.7802690582959642
# The Hidden Layer shape [37, 21] has accuracy of 0.7847533632286996
# The Hidden Layer shape [37, 22] has accuracy of 0.7937219730941704
# The Hidden Layer shape [37, 23] has accuracy of 0.7802690582959642
# The Hidden Layer shape [37, 24] has accuracy of 0.7802690582959642
# The Hidden Layer shape [37, 25] has accuracy of 0.7757847533632287
# The Hidden Layer shape [37, 26] has accuracy of 0.7847533632286996
# The Hidden Layer shape [37, 27] has accuracy of 0.8071748878923767
# The Hidden Layer shape [37, 28] has accuracy of 0.7847533632286996
# The Hidden Layer shape [37, 29] has accuracy of 0.7802690582959642
# The Hidden Layer shape [37, 30] has accuracy of 0.7802690582959642
# The Hidden Layer shape [37, 31] has accuracy of 0.7802690582959642
# The Hidden Layer shape [37, 32] has accuracy of 0.757847533632287
# The Hidden Layer shape [37, 33] has accuracy of 0.7892376681614349
# The Hidden Layer shape [37, 34] has accuracy of 0.7757847533632287
# The Hidden Layer shape [37, 35] has accuracy of 0.7892376681614349
# The Hidden Layer shape [37, 36] has accuracy of 0.7757847533632287
# The Hidden Layer shape [37, 37] has accuracy of 0.7668161434977578
# The Hidden Layer shape [37, 38] has accuracy of 0.7713004484304933
# The Hidden Layer shape [37, 39] has accuracy of 0.7937219730941704
# The Hidden Layer shape [37, 40] has accuracy of 0.7802690582959642
# The Hidden Layer shape [38, 20] has accuracy of 0.7623318385650224
# The Hidden Layer shape [38, 21] has accuracy of 0.7937219730941704
# The Hidden Layer shape [38, 22] has accuracy of 0.7757847533632287
# The Hidden Layer shape [38, 23] has accuracy of 0.7488789237668162
# The Hidden Layer shape [38, 24] has accuracy of 0.7623318385650224
# The Hidden Layer shape [38, 25] has accuracy of 0.7802690582959642
# The Hidden Layer shape [38, 26] has accuracy of 0.7623318385650224
# The Hidden Layer shape [38, 27] has accuracy of 0.7802690582959642
# The Hidden Layer shape [38, 28] has accuracy of 0.7937219730941704
# The Hidden Layer shape [38, 29] has accuracy of 0.7533632286995515
# The Hidden Layer shape [38, 30] has accuracy of 0.7937219730941704
# The Hidden Layer shape [38, 31] has accuracy of 0.7802690582959642
# The Hidden Layer shape [38, 32] has accuracy of 0.7802690582959642
# The Hidden Layer shape [38, 33] has accuracy of 0.7623318385650224
# The Hidden Layer shape [38, 34] has accuracy of 0.7713004484304933
# The Hidden Layer shape [38, 35] has accuracy of 0.7937219730941704
# The Hidden Layer shape [38, 36] has accuracy of 0.7713004484304933
# The Hidden Layer shape [38, 37] has accuracy of 0.7937219730941704
# The Hidden Layer shape [38, 38] has accuracy of 0.7757847533632287
# The Hidden Layer shape [38, 39] has accuracy of 0.7847533632286996
# The Hidden Layer shape [38, 40] has accuracy of 0.7757847533632287
# The Hidden Layer shape [39, 20] has accuracy of 0.7847533632286996
# The Hidden Layer shape [39, 21] has accuracy of 0.7802690582959642
# The Hidden Layer shape [39, 22] has accuracy of 0.7847533632286996
# The Hidden Layer shape [39, 23] has accuracy of 0.7713004484304933
# The Hidden Layer shape [39, 24] has accuracy of 0.7847533632286996
# The Hidden Layer shape [39, 25] has accuracy of 0.7892376681614349
# The Hidden Layer shape [39, 26] has accuracy of 0.7892376681614349
# The Hidden Layer shape [39, 27] has accuracy of 0.7892376681614349
# The Hidden Layer shape [39, 28] has accuracy of 0.7623318385650224
# The Hidden Layer shape [39, 29] has accuracy of 0.7847533632286996
# The Hidden Layer shape [39, 30] has accuracy of 0.7847533632286996
# The Hidden Layer shape [39, 31] has accuracy of 0.7668161434977578
# The Hidden Layer shape [39, 32] has accuracy of 0.7713004484304933
# The Hidden Layer shape [39, 33] has accuracy of 0.7802690582959642
# The Hidden Layer shape [39, 34] has accuracy of 0.757847533632287
# The Hidden Layer shape [39, 35] has accuracy of 0.7847533632286996
# The Hidden Layer shape [39, 36] has accuracy of 0.7757847533632287
# The Hidden Layer shape [39, 37] has accuracy of 0.7757847533632287
# The Hidden Layer shape [39, 38] has accuracy of 0.7892376681614349
# The Hidden Layer shape [39, 39] has accuracy of 0.7892376681614349
# The Hidden Layer shape [39, 40] has accuracy of 0.7937219730941704
# The Hidden Layer shape [40, 20] has accuracy of 0.7757847533632287
# The Hidden Layer shape [40, 21] has accuracy of 0.7757847533632287
# The Hidden Layer shape [40, 22] has accuracy of 0.7892376681614349
# The Hidden Layer shape [40, 23] has accuracy of 0.7623318385650224
# The Hidden Layer shape [40, 24] has accuracy of 0.7892376681614349
# The Hidden Layer shape [40, 25] has accuracy of 0.7757847533632287
# The Hidden Layer shape [40, 26] has accuracy of 0.7623318385650224
# The Hidden Layer shape [40, 27] has accuracy of 0.7533632286995515
# The Hidden Layer shape [40, 28] has accuracy of 0.7713004484304933
# The Hidden Layer shape [40, 29] has accuracy of 0.7892376681614349
# The Hidden Layer shape [40, 30] has accuracy of 0.7982062780269058
# The Hidden Layer shape [40, 31] has accuracy of 0.7892376681614349
# The Hidden Layer shape [40, 32] has accuracy of 0.7757847533632287
# The Hidden Layer shape [40, 33] has accuracy of 0.7623318385650224
# The Hidden Layer shape [40, 34] has accuracy of 0.7757847533632287
# The Hidden Layer shape [40, 35] has accuracy of 0.7668161434977578
# The Hidden Layer shape [40, 36] has accuracy of 0.7623318385650224
# The Hidden Layer shape [40, 37] has accuracy of 0.7892376681614349
# The Hidden Layer shape [40, 38] has accuracy of 0.7713004484304933
# The Hidden Layer shape [40, 39] has accuracy of 0.7847533632286996
# The Hidden Layer shape [40, 40] has accuracy of 0.757847533632287
# 0.8161434977578476 [33, 37]

# %%
import random
# to use on the prediction, not testing accuracy
test_df_full= pd.read_csv('test.csv')
test_df = test_df_full.drop(["PassengerId","Name","Cabin","Ticket"],axis=1)
## check for NaN values with test_df["Embarked"].isnull().values.any()
## Age and Fare are missing some values.
## We will use a random number between standard variation and mean to fill the NaN values
test_df['Sex'].replace('male',0,inplace=True)
test_df['Sex'].replace('female',1,inplace=True)
test_df['Embarked'].replace('S',0,inplace=True)
test_df['Embarked'].replace('C',1,inplace=True)
test_df['Embarked'].replace('Q',1,inplace=True)
## Fill Age
mean_age = test_df["Age"].mean() # around 30
#standard deviation
std = test_df["Age"].std() # around 14
# replace empty age with rando between mean and standard deviation
test_df['Age'].fillna(random.randint(int(std),int(mean_age)), inplace=True)
## Fill Fare
mean_fare = test_df["Fare"].mean() # 
#standard deviation
std_fare = test_df["Fare"].std() # around 14
# replace empty age with rando between mean and standard deviation
test_df['Fare'].fillna(random.uniform(std_fare,mean_fare), inplace=True)
test_df.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0       3    0  34.5      0      0   7.8292         1
# 1       3    1  47.0      1      0   7.0000         0
# 2       2    0  62.0      0      0   9.6875         1
# 3       3    0  27.0      0      0   8.6625         0
# 4       3    1  22.0      1      1  12.2875         0

# %%
test_df["Fare"].isnull().values.any()
# Out:
# False

# %%
test_pred = model.predict(test_df)

# %%
test_df["Survived"]=test_pred
test_df["PassengerId"] = test_df_full["PassengerId"]

# %%
test_df.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Survived  PassengerId
# 0       3    0  34.5      0      0   7.8292         1         0          892
# 1       3    1  47.0      1      0   7.0000         0         0          893
# 2       2    0  62.0      0      0   9.6875         1         0          894
# 3       3    0  27.0      0      0   8.6625         0         0          895
# 4       3    1  22.0      1      1  12.2875         0         1          896

# %%
test_df = test_df.drop(["Pclass","Sex","Age","SibSp","Parch","Fare","Embarked"],axis=1)

# %%
test_df.head()
# Out:
#    Survived  PassengerId
# 0         0          892
# 1         0          893
# 2         0          894
# 3         0          895
# 4         1          896

# %%
test_df.to_csv('titanic_sklearn_testpredictions.csv', index=False)
